# %% [markdown]
# # GenAI Workshop
# ## Lesson: Setup Colab
#
# This notebook is intended to setup the API key for using google models. We only have to do this once.

# %% [markdown]
# ## Step 1: Create an API key

# %% [markdown]
# You can [create](https://aistudio.google.com/app/apikey) your API key using Google AI Studio with a single click.
#
# Remember to treat your API key like a password. Since we are using Google Colab, we store the key in Colab Secrets.

# %% [markdown]
# ## Step 2: Add your key to Colab Secrets
#
# Add your API key to the Colab Secrets manager to securely store it.
#
# 1. Open your Google Colab notebook and click on the 🔑 **Secrets** tab in the left panel.
#
#    <img src="https://storage.googleapis.com/generativeai-downloads/images/secrets.jpg" alt="You can find the Secrets tab on the left panel." width=50%>
#
# 2. Create a new secret with the name `GOOGLE_API_KEY`.
# 3. Copy and paste your API key into the `Value` input box of `GOOGLE_API_KEY`.
# 4. Toggle the button on the left to allow all notebooks access to the secret.
#
# ### Environment setup (only running local Jupyter inside VSCode)
# To run this notebook locally, create and select a Python 3.9 venv with the right packages.
#
# 1. Create and activate the env (use the system Python 3.9 or any python <=3.12):
#    ```bash
#    /usr/bin/python3.12 -m venv .venv
#    source .venv/bin/activate
#    ```
# 2. BETTER use python3.12 and use:
#    ```bash
#    pip install chromadb pydantic-settings langchain-text-splitters google-genai ipykernel pandas
#    ```
# 2. ONLY of you have outdated python3.9: Install the deps (note: chromadb 0.4.24 needs numpy<2):
#    ```bash
#    pip install "chromadb==0.4.24" "numpy<2" pydantic-settings langchain-text-splitters google-genai ipykernel
#    ```
# 3. Register/select the kernel in VS Code / Jupyter:
#    ```bash
#    python -m ipykernel install --user --name .venv --display-name ".venv"
#    ```
#    Then choose the ".venv" kernel in the notebook UI and restart the kernel before running cells.

# %% [markdown]
# ## Step 3: Verify the configuration
# Let's verify if the setup was correct. If an error occurs during client initialization, make sure you exactly followed the steps as described.

# %%
import os
from google import genai
from google.genai import types

# Load the colab library for accessing the colab secrets
if not os.getenv("GOOGLE_API_KEY"):
  from google.colab import userdata

# Load the api key 
  GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
else:
  GOOGLE_API_KEY=os.getenv("GOOGLE_API_KEY")

# %%
# Load the gemini sdk
from google import genai

# Initialze the client
client = genai.Client(api_key=GOOGLE_API_KEY)

# List google models
print("Google Models:\n")
for model in client.models.list():
    print(model.display_name)

# Close the client
client.close()
# Out:
# Google Models:
#
# Embedding Gecko
# Gemini 2.5 Flash
# Gemini 2.5 Pro
# Gemini 2.0 Flash Experimental
# Gemini 2.0 Flash
# Gemini 2.0 Flash 001
# Gemini 2.0 Flash-Lite 001
# Gemini 2.0 Flash-Lite
# Gemini 2.0 Flash-Lite Preview 02-05
# Gemini 2.0 Flash-Lite Preview
# Gemini Experimental 1206
# Gemini 2.5 Flash Preview TTS
# Gemini 2.5 Pro Preview TTS
# Gemma 3 1B
# Gemma 3 4B
# Gemma 3 12B
# Gemma 3 27B
# Gemma 3n E4B
# Gemma 3n E2B
# Gemini Flash Latest
# Gemini Flash-Lite Latest
# Gemini Pro Latest
# Gemini 2.5 Flash-Lite
# Nano Banana
# Nano Banana
# Gemini 2.5 Flash Preview Sep 2025
# Gemini 2.5 Flash-Lite Preview Sep 2025
# Gemini 3 Pro Preview
# Gemini 3 Flash Preview
# Nano Banana Pro
# Nano Banana Pro
# Gemini Robotics-ER 1.5 Preview
# Gemini 2.5 Computer Use Preview 10-2025
# Deep Research Pro Preview (Dec-12-2025)
# Embedding 001
# Text Embedding 004
# Gemini Embedding Experimental 03-07
# Gemini Embedding Experimental
# Gemini Embedding 001
# Model that performs Attributed Question Answering.
# Imagen 4 (Preview)
# Imagen 4 Ultra (Preview)
# Imagen 4
# Imagen 4 Ultra
# Imagen 4 Fast
# Veo 2
# Veo 3
# Veo 3 fast
# Veo 3.1
# Veo 3.1 fast
# Gemini 2.5 Flash Native Audio Latest
# Gemini 2.5 Flash Native Audio Preview 09-2025
# Gemini 2.5 Flash Native Audio Preview 12-2025
